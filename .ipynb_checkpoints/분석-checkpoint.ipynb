# %%
import requests
import pandas as pd
import xmltodict
import json
import numpy as np

# %%
dong_code = pd.read_csv('data/법정동코드 전체자료.csv', sep = '\t')  #www.code.go.kr 자료
dong_code = dong_code[dong_code['폐지여부']=='존재']

# %%
dong_code['법정동코드_re'] = list(str(code)[:5] for code in list(dong_code['법정동코드']))

# %%
dong_code_re = dong_code.drop_duplicates(subset=['법정동코드_re'], keep='first').reset_index()

# %%
dong_code_re
# Out:
#      index       법정동코드          법정동명 폐지여부 법정동코드_re
# 0        0  1100000000         서울특별시   존재    11000
# 1        1  1111000000     서울특별시 종로구   존재    11110
# 2       94  1114000000      서울특별시 중구   존재    11140
# 3      179  1117000000     서울특별시 용산구   존재    11170
# 4      229  1120000000     서울특별시 성동구   존재    11200
# ..     ...         ...           ...  ...      ...
# 272  45372  4888000000      경상남도 거창군   존재    48880
# 273  45486  4889000000      경상남도 합천군   존재    48890
# 274  46076  5000000000       제주특별자치도   존재    50000
# 275  46077  5011000000   제주특별자치도 제주시   존재    50110
# 276  46213  5013000000  제주특별자치도 서귀포시   존재    50130
#
# [277 rows x 5 columns]

# %%
data = pd.read_csv('RealEstateTransactionKorea/dataRefined/0_아파트 매매_all_reordered.tsv', delimiter='\t', encoding='utf-8')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
len(data)
# Out:
# 8143138

# %%
data.head(5)
# Out:
#                    pnu         x          y  count  yyyymmdd   area  price  \
# 0  1111010100100560045  952965.7  1954226.8     54  20120420  68.43  51500
# 1  1111010100100560045  952964.4  1954227.1     54  20060505  78.78  43000
# 2  1111010100100560045  952965.7  1954227.4     54  20090512  78.78  56500
# 3  1111010100100560045  952965.7  1954225.7     54  20101231  78.78  51000
# 4  1111010100100560045  952965.2  1954225.7     54  20111011  78.78  53000
#
#    withoutRent  builtyear            시군구   단지명  층         도로명
# 0            1     2000.0  서울특별시 종로구 청운동  청운현대  1  자하문로33길 43
# 1            1     2000.0  서울특별시 종로구 청운동  청운현대  1  자하문로33길 43
# 2            1     2000.0  서울특별시 종로구 청운동  청운현대  1  자하문로33길 43
# 3            1     2000.0  서울특별시 종로구 청운동  청운현대  3  자하문로33길 43
# 4            1     2000.0  서울특별시 종로구 청운동  청운현대  2  자하문로33길 43

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8143138 entries, 0 to 8143137
# Data columns (total 13 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   pnu          object
#  1   x            float64
#  2   y            float64
#  3   count        int64
#  4   yyyymmdd     int64
#  5   area         float64
#  6   price        int64
#  7   withoutRent  int64
#  8   builtyear    float64
#  9   시군구          object
#  10  단지명          object
#  11  층            int64
#  12  도로명          object
# dtypes: float64(4), int64(5), object(4)
# memory usage: 807.7+ MB

# %%
data = data.astype({'yyyymmdd':'str'})

# %%
set(date[:4] for date in data['yyyymmdd'])
# Out:
# {'2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020'}

# %%
data_re = data[~data['yyyymmdd'].str.startswith('2006')]
data_re = data_re[~data_re['yyyymmdd'].str.startswith('2007')]
data_re = data_re[~data_re['yyyymmdd'].str.startswith('2008')]
data_re = data_re[~data_re['yyyymmdd'].str.startswith('2009')]
data_re = data_re[~data_re['yyyymmdd'].str.startswith('2010')]
data_re = data_re[~data_re['yyyymmdd'].str.startswith('2011')]
data_re = data_re[~data_re['yyyymmdd'].str.startswith('2012')]
data_re = data_re[~data_re['yyyymmdd'].str.startswith('2013')]
data_re = data_re[~data_re['yyyymmdd'].str.startswith('2014')]
data_re = data_re[~data_re['yyyymmdd'].str.startswith('2015')]

# %%
set(date[:4] for date in data_re['yyyymmdd'])
# Out:
# {'2016', '2017', '2018', '2019', '2020'}

# %%
data_re.head(50)
# Out:
#                      pnu         x          y  count  yyyymmdd    area  \
# 8    1111010100100560045  952967.2  1954226.2     54  20181031   78.78
# 22   1111010100100560045  952965.7  1954228.9     54  20170718   84.51
# 23   1111010100100560045  952965.3  1954226.2     54  20170916   84.51
# 24   1111010100100560045  952965.6  1954228.6     54  20171129   84.51
# 25   1111010100100560045  952964.8  1954228.0     54  20180403   84.51
# 26   1111010100100560045  952965.4  1954225.7     54  20191009   84.51
# 28   1111010100100560045  952965.1  1954227.7     54  20170911  103.67
# 32   1111010100100560045  952962.8  1954227.1     54  20161202  129.76
# 33   1111010100100560045  952966.4  1954225.4     54  20171219  129.76
# 34   1111010100100560045  952964.2  1954227.3     54  20180202  129.76
# 35   1111010100100560045  952964.8  1954227.2     54  20190515  129.76
# 49   1111010200100060013  953014.1  1953927.1     12  20170926   84.82
# ...

# %%
MYKEY = "sh1BLNic10zE0pynUHLuP0%2FDxTd5Fi4m5%2B4CojHK%2B%2BXTxH9ykyO3yVPROWHp3zsR9%2BB38%2BkIGmWgHB%2BYfmUB6A%3D%3D"
region_code = '11110'
month = '201512'

months = 

url = f"http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTrade?serviceKey={MYKEY}&LAWD_CD={region_code}&DEAL_YM={month}"


req = requests.get(url)
xpars = xmltodict.parse(req.text)

jsonDump = json.dumps(xpars)
jsonBody = json.loads(jsonDump)

pd.DataFrame(jsonBody['response']['body'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-67eb438869f9> in <module>
#      11 jsonBody = json.loads(jsonDump)
#      12
# ---> 13 pd.DataFrame(jsonBody['response']['body'])
#
# KeyError: 'body'

# %%
jsonBody['response']
# Out:
# {'header': {'resultCode': '99',
#   'resultMsg': 'SERVICE KEY IS NOT REGISTERED ERROR.'}}
